# %%
import polars as pl

# %%
## Config

path = "C:\\Users\\Arnold\\OneDrive\\Desktop\\CAPSTONE PROJECT\\farming_risk_regions\\data\\interim\\yield_data\\corn_yields_20251021.csv"

# %%
yield_data = pl.read_csv(path)

# %%
yield_data.head()
# Out:
# shape: (5, 9)
# ┌──────┬──────┬───────┬────────┬───┬─────────────────────┬─────────────┬────────────┬────────────┐
# │ crop ┆ year ┆ state ┆ county ┆ … ┆ area_harvested_unit ┆ yield_value ┆ yield_unit ┆ data_found │
# │ ---  ┆ ---  ┆ ---   ┆ ---    ┆   ┆ ---                 ┆ ---         ┆ ---        ┆ ---        │
# │ str  ┆ i64  ┆ str   ┆ str    ┆   ┆ str                 ┆ f64         ┆ str        ┆ bool       │
# ╞══════╪══════╪═══════╪════════╪═══╪═════════════════════╪═════════════╪════════════╪════════════╡
# │ CORN ┆ 2014 ┆ IA    ┆ Story  ┆ … ┆ ACRES               ┆ 169.9       ┆ BU / ACRE  ┆ true       │
# │ CORN ┆ 2015 ┆ IA    ┆ Story  ┆ … ┆ ACRES               ┆ 188.0       ┆ BU / ACRE  ┆ true       │
# │ CORN ┆ 2016 ┆ IA    ┆ Story  ┆ … ┆ ACRES               ┆ 211.9       ┆ BU / ACRE  ┆ true       │
# │ CORN ┆ 2017 ┆ IA    ┆ Story  ┆ … ┆ ACRES               ┆ 200.3       ┆ BU / ACRE  ┆ true       │
# ...

# %%
yield_data.tail()
# Out:
# shape: (5, 9)
# ┌──────┬──────┬───────┬────────┬───┬─────────────────────┬─────────────┬────────────┬────────────┐
# │ crop ┆ year ┆ state ┆ county ┆ … ┆ area_harvested_unit ┆ yield_value ┆ yield_unit ┆ data_found │
# │ ---  ┆ ---  ┆ ---   ┆ ---    ┆   ┆ ---                 ┆ ---         ┆ ---        ┆ ---        │
# │ str  ┆ i64  ┆ str   ┆ str    ┆   ┆ str                 ┆ f64         ┆ str        ┆ bool       │
# ╞══════╪══════╪═══════╪════════╪═══╪═════════════════════╪═════════════╪════════════╪════════════╡
# │ CORN ┆ 2020 ┆ MO    ┆ Saline ┆ … ┆ ACRES               ┆ 195.7       ┆ BU / ACRE  ┆ true       │
# │ CORN ┆ 2021 ┆ MO    ┆ Saline ┆ … ┆ null                ┆ null        ┆ null       ┆ false      │
# │ CORN ┆ 2022 ┆ MO    ┆ Saline ┆ … ┆ ACRES               ┆ null        ┆ null       ┆ true       │
# │ CORN ┆ 2023 ┆ MO    ┆ Saline ┆ … ┆ ACRES               ┆ 175.7       ┆ BU / ACRE  ┆ true       │
# ...

# %%
yield_data.describe()
# Out:
# shape: (9, 10)
# ┌────────────┬──────┬──────────┬───────┬───┬───────────────┬─────────────┬────────────┬────────────┐
# │ statistic  ┆ crop ┆ year     ┆ state ┆ … ┆ area_harveste ┆ yield_value ┆ yield_unit ┆ data_found │
# │ ---        ┆ ---  ┆ ---      ┆ ---   ┆   ┆ d_unit        ┆ ---         ┆ ---        ┆ ---        │
# │ str        ┆ str  ┆ f64      ┆ str   ┆   ┆ ---           ┆ f64         ┆ str        ┆ f64        │
# │            ┆      ┆          ┆       ┆   ┆ str           ┆             ┆            ┆            │
# ╞════════════╪══════╪══════════╪═══════╪═══╪═══════════════╪═════════════╪════════════╪════════════╡
# │ count      ┆ 121  ┆ 121.0    ┆ 121   ┆ … ┆ 105           ┆ 103.0       ┆ 103        ┆ 121.0      │
# │ null_count ┆ 0    ┆ 0.0      ┆ 0     ┆ … ┆ 16            ┆ 18.0        ┆ 18         ┆ 0.0        │
# │ mean       ┆ null ┆ 2019.0   ┆ null  ┆ … ┆ null          ┆ 199.863107  ┆ null       ┆ 0.867769   │
# ...
